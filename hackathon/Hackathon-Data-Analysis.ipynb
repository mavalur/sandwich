# %%
# imports a library 'pandas', names it as 'pd'

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# !ls -al
# Out:
# total 78952
# drwxr-xr-x  16 satishterala  staff      544 Dec 21 11:49 .
# drwxr-xr-x  17 satishterala  staff      578 Dec 21 02:38 ..
# drwxr-xr-x   3 satishterala  staff      102 Dec 21 09:42 .ipynb_checkpoints
# -rw-r--r--   1 satishterala  staff    39986 Dec 21 11:49 Hackathon-Data-Analysis.ipynb
# -rw-r--r--   1 satishterala  staff   264478 Dec 21 02:38 Intro_to_Pandas.ipynb
# -rw-r--r--   1 satishterala  staff  2484241 Dec 21 09:48 cl-app2app.json
# -rw-r--r--   1 satishterala  staff  7810071 Dec 21 09:47 cl-cleanapps.json
# -rw-r--r--   1 satishterala  staff  1799611 Dec 21 09:46 cl-grmmember.json
# -rw-r--r--   1 satishterala  staff   682056 Dec 21 09:45 cl-users-grp.json
# -rw-r--r--   1 satishterala  staff  8004319 Dec 21 09:45 cl-users.json
# -rw-r--r--   1 satishterala  staff  7225068 Dec 21 00:13 cmdb_ci_service_list.json
# -rw-r--r--   1 satishterala  staff  2333220 Dec 21 00:17 cmdb_rel_ci_list.json
# -rw-r--r--   1 satishterala  staff  1685529 Dec 21 00:14 sys_user_grmember_list.json
# -rw-r--r--   1 satishterala  staff   634398 Dec 21 00:10 sys_user_group_list.json
# -rw-r--r--   1 satishterala  staff  7427069 Dec 21 00:07 sys_user_list.json
# -rw-r--r--   1 satishterala  staff     8805 Dec 21 00:15 u_business_application_list.json

# %%
def clean_json_return_df(filename,tempfilename):
    with open(filename) as f:
        rec_dict = json.load(f)
        dict_list=[]
        for line in rec_dict['records']:
            int_dicts = {}
            for key,val in line.iteritems():
                int_dicts[key]=val
            dict_list.append(int_dicts)
    
        with open(tempfilename,'w')as outfile:
            json.dump(dict_list,outfile)
    return pd.read_json(tempfilename)

# %%
from pymongo import MongoClient
def insert_clean_json_mongo(filename,tempfilename,collection_name):
    client = MongoClient("mongodb://sandwich:sandwich@ds035385.mongolab.com:35385/sandwich")
    db = client.sandwich
    df =  clean_json_return_df(filename,tempfilename)
    records = json.loads(df.T.to_json()).values()
    db.collection_name.insert(records)

# %%
users = clean_json_return_df('sys_user_list.json','cl-users.json')
users_grp = insert_clean_json_mongo('sys_user_group_list.json','cl-users-grp.json')
grmmember = clean_json_return_df('sys_user_grmember_list.json','cl-grmmember.json')
app_to_app = clean_json_return_df('cmdb_rel_ci_list.json','cl-app2app.json')
app_to_app = clean_json_return_df('cmdb_rel_ci_list.json','cl-app2app.json')

# %%
apps = clean_json_return_df('cmdb_ci_service_list.json','cl-apps.json')

# %%
app_cols = ["support_group","subcategory","u_business_unit","busines_criticality","u_type","u_wmc_app_id","u_wmc_central_category","used_for","u_support_tier_2","u_level","u_business_domain"]
apps[app_cols]
# Out:
#                              support_group subcategory  \
# 0                 Asset Allocation Support
# 1                     Fixed Income Support
# 2                     Fixed Income Support
# 3                     Fixed Income Support
# 4          Derivatives Operations App Team
# 5          Derivatives Operations App Team
# 6                    Non-IT Supported Apps
# 7                          Telecom Support
# 8                    Non-IT Supported Apps
# 9                          Trading Support
# 10                     Derivatives Support
# 11                          Geneva Support
# 12                   Non-IT Supported Apps
# 13                        Solutions Center
# 14                   Non-IT Supported Apps
# 15                         Trading Support
# 16                         Trading Support
# 17                        DataFlux Support
# 18
# 19                   Non-IT Supported Apps
# 20    Legal and Compliance Systems Support
# 21                         Trading Support
# 22                    Fixed Income Support
# 23                        Solutions Center
# 24                      Geneva Development
# 25                    Alternatives Support
# 26                   Non-IT Supported Apps
# 27        GRG Client Support - Tier 1 Team
# 28               Logical Data Architecture
# 29                        Solutions Center
# ...                                    ...         ...
# 2614       Corporate Applications App Team
# 2615                            Facilities
# 2616                Data Center Management
# 2617                   Performance Support
# 2618
# 2619                Incentive Comp Support
# 2620                   Security Operations
# 2621
# 2622                   Batch Cycle Support
# 2623                 Non-IT Supported Apps
# 2624                  Fixed Income Support
# 2625      GRG Client Support - Tier 1 Team
# 2626                   Batch Cycle Support
# 2627         Sharepoint Collaboration Team
# 2628                            IC Support
# 2629
# 2630                      Solutions Center
# 2631                       Desktop Support
# 2632                 Non-IT Supported Apps
# 2633                      Solutions Center
# 2634
# 2635
# 2636                 Non-IT Supported Apps
# 2637                  Fixed Income Support
# 2638
# 2639                       Desktop Support
# 2640  Legal and Compliance Systems Support
# 2641                        Wintel Support
# 2642       Derivatives Operations App Team
# 2643  Legal and Compliance Systems Support
#
#                            u_business_unit            busines_criticality  \
# 0                   Information Technology        4 - Important - Day Two
# 1                                  Trading        4 - Important - Day Two
# 2                               Investment        4 - Important - Day Two
# 3                               Investment        4 - Important - Day Two
# 4                Investment Administration        4 - Important - Day Two
# 5                Investment Administration  6 - Non-Critical - When Ready
# 6                Investment Administration        4 - Important - Day Two
# 7                   Information Technology  0 - Critical - Infrastructure
# 8                               Investment    5 - Necessary - End of Week
# 9                                  Trading       1 - Critical - Immediate
# 10                              Investment       2 - Essential - Intraday
# 11               Investment Administration       1 - Critical - Immediate
# 12    Client and Global Relationship Group    5 - Necessary - End of Week
# 13                  Information Technology        4 - Important - Day Two
# 14               Investment Administration    5 - Necessary - End of Week
# 15                                 Trading      3 - Required - End of Day
# 16                                 Trading       1 - Critical - Immediate
# 17                  Information Technology        4 - Important - Day Two
# 18                  Information Technology                        9 - TBD
# 19               Investment Administration    5 - Necessary - End of Week
# 20                    Legal and Compliance             8 - Non-Production
# 21                                 Trading       1 - Critical - Immediate
# 22                  Information Technology       1 - Critical - Immediate
# 23                  Information Technology       2 - Essential - Intraday
# 24                  Information Technology                        9 - TBD
# 25                              Investment       2 - Essential - Intraday
# 26               Investment Administration        4 - Important - Day Two
# 27    Client and Global Relationship Group  6 - Non-Critical - When Ready
# 28                  Information Technology       2 - Essential - Intraday
# 29                  Information Technology      3 - Required - End of Day
# ...                                    ...                            ...
# 2614                             Corporate  6 - Non-Critical - When Ready
# 2615                Information Technology                        9 - TBD
# 2616                Information Technology  0 - Critical - Infrastructure
# 2617             Investment Administration        4 - Important - Day Two
# 2618                Information Technology                        9 - TBD
# 2619                               Finance    5 - Necessary - End of Week
# 2620  Client and Global Relationship Group       2 - Essential - Intraday
# 2621                Information Technology                        9 - TBD
# 2622                Information Technology                        9 - TBD
# 2623             Investment Administration    5 - Necessary - End of Week
# 2624                            Investment  6 - Non-Critical - When Ready
# 2625  Client and Global Relationship Group        4 - Important - Day Two
# 2626                Information Technology        4 - Important - Day Two
# 2627  Client and Global Relationship Group        4 - Important - Day Two
# 2628             Investment Administration                        9 - TBD
# 2629                Information Technology                        9 - TBD
# 2630                       Human Resources    5 - Necessary - End of Week
# 2631                Information Technology                        9 - TBD
# 2632  Client and Global Relationship Group  6 - Non-Critical - When Ready
# 2633                Information Technology        4 - Important - Day Two
# 2634                Information Technology                        9 - TBD
# 2635                Information Technology                        9 - TBD
# 2636                            Investment      3 - Required - End of Day
# 2637                            Investment      3 - Required - End of Day
# 2638                Information Technology                        9 - TBD
# 2639                Information Technology  0 - Critical - Infrastructure
# 2640                  Legal and Compliance        4 - Important - Day Two
# 2641                Information Technology             8 - Non-Production
# 2642             Investment Administration      3 - Required - End of Day
# 2643                  Legal and Compliance    5 - Necessary - End of Week
#
#                         u_type u_wmc_app_id u_wmc_central_category  \
# 0              Business Facing       SFIRAN                   None
# 1              Business Facing        FIMON                 Client
# 2                           MC          FRS                   None
# 3              Business Facing       MACDBA                   None
# 4              Business Facing       DOSTCC                   None
# 5              Business Facing       DOSMGN                   None
# 6              Business Facing       BZ0124                   None
# 7              Business Facing        AVMXE                   None
# 8              Business Facing       BZ0346                   None
# 9              Business Facing          CTM                   None
# 10             Business Facing          DCE                   None
# 11    Module - Business Facing          GEN                   None
# 12             Business Facing       BZ0203                   None
# 13            Desktop Software       PRJECT                   None
# 14             Business Facing       BZ0043                   None
# 15             Business Facing        EQMTM                   None
# 16    Module - Resource Facing      GEQLNCH                   None
# 17                   IT Facing         DFLX                   None
# 18             Business Facing                                None
# 19             Business Facing       BZ0151                   None
# 20             Business Facing          CLE                   None
# 21                          MR       OMSFX1                   None
# 22                          MC         IV2K                   None
# 23             Business Facing         MYPC                   Firm
# 24             Business Facing                                None
# 25             Business Facing         AAMD                   None
# 26             Business Facing       BZ0162                   None
# 27             Business Facing         QPRO                 Client
# 28                   IT Facing        WMCSS                   None
# 29                   IT Facing          VDI                   None
# ...                        ...          ...                    ...
# 2614           Business Facing       UNIFLO                   None
# 2615         Business Function                                None
# 2616               IT Function                                None
# 2617  Module - Business Facing        PMTDR                   None
# 2618           Business Facing                                None
# 2619  Module - Business Facing          IPM                   None
# 2620           Business Facing       AKAMAI                   None
# 2621           Business Facing                                None
# 2622               IT Function                                None
# 2623           Business Facing       BZ0095                   None
# 2624  Module - Resource Facing       PMTCES                   None
# 2625           Business Facing        PCSBK                   None
# 2626                 IT Facing         WLMP                   None
# 2627           Resource Facing        MTLGX                   None
# 2628         Business Function                                None
# 2629           Business Facing                                None
# 2630           Business Facing        SPHRC                   Self
# 2631               IT Function                                None
# 2632           Business Facing       BZ0247                   None
# 2633          Desktop Software        ADOFL                   None
# 2634           Business Facing                                None
# 2635           Business Facing                                None
# 2636           Business Facing       BZ0292                   None
# 2637                 IT Facing           VS                   None
# 2638           Business Facing                                None
# 2639           Business Facing        TREIK                   None
# 2640           Business Facing          RMS                   None
# 2641                 IT Facing         FILE                   None
# 2642  Module - Business Facing         VMAT                   None
# 2643  Module - Business Facing         CAT2                   None
#
#         used_for                      u_support_tier_2 u_level  \
# 0     Production                  Alternatives Support     (1)
# 1     Production                                  FIPC     (1)
# 2     Production                                  FIPC     (1)
# 3     Production  FIRST (Fixed Income Rapid Solutions)     (1)
# 4     Production                           DOS Support     (1)
# 5     Production       Derivatives Operations App Team     (1)
# 6     Production                 Non-IT Supported Apps     (1)
# 7     Production                       Telecom Support     (1)
# 8     Production                 Non-IT Supported Apps     (1)
# 9     Production                       Trading Support     (1)
# 10    Production                   Derivatives Support     (1)
# 11    Production                    Geneva Development     (1)
# 12    Production                 Non-IT Supported Apps     (1)
# 13    Production                       Desktop Support     (1)
# 14    Production                 Non-IT Supported Apps     (1)
# 15    Production                        GTS EQ Support     (1)
# 16    Production        Trading GTS Equity Development     (1)
# 17    Production                      DataFlux Support
# 18    Production                                           (1)
# 19    Production                 Non-IT Supported Apps     (1)
# 20    Production     Legal & Compliance Tier 2 Support     (1)
# 21    Production                       Trading Support     (1)
# 22    Production                                  FIPC     (1)
# 23    Production                        Citrix Support     (1)
# 24    Production                    Geneva Development     (1)
# 25    Production              Asset Allocation Support     (1)
# 26    Production                 Non-IT Supported Apps     (1)
# 27    Production                    GRG Client Support     (1)
# 28    Production             Logical Data Architecture     (1)
# 29    Production                        Citrix Support     (1)
# ...          ...                                   ...     ...
# 2614  Production       Corporate Applications App Team     (1)
# 2615  Production                            Facilities       1
# 2616  Production                                             1
# 2617  Production                   Performance Support     (1)
# 2618  Production                                           (1)
# 2619  Production       Corporate Applications App Team     (1)
# 2620  Production                   Security Operations     (1)
# 2621  Production                                           (1)
# 2622  Production                                             1
# 2623  Production                 Non-IT Supported Apps     (1)
# 2624  Production                  Fixed Income Support     (1)
# 2625  Production                PCS Publishing Systems     (1)
# 2626  Production                   Batch Cycle Support     (1)
# 2627  Production         Sharepoint Collaboration Team     (1)
# 2628  Production                           ISP Support       1
# 2629  Production                                           (1)
# 2630  Production     Corporate HR Applications Support     (1)
# 2631  Production                                             1
# 2632  Production                 Non-IT Supported Apps     (1)
# 2633  Production                       Desktop Support     (1)
# 2634  Production                                           (1)
# 2635  Production                                           (1)
# 2636  Production                 Non-IT Supported Apps     (1)
# 2637  Production                                  FIPC     (1)
# 2638  Production                                           (1)
# 2639  Production                   Market Data Support     (1)
# 2640  Production     Legal & Compliance Tier 2 Support     (1)
# 2641  Production                        Wintel Support     (1)
# 2642  Production       Derivatives Operations App Team     (1)
# 2643  Production     Legal & Compliance Tier 2 Support     (1)
#
#                       u_business_domain
# 0                                  Risk
# 1                  Fixed Income Trading
# 2                Portfolio Construction
# 3     Fixed Income Portfolio Management
# 4                Derivatives Operations
# 5                Derivatives Operations
# 6                   Fund Administration
# 7                             Telephone
# 8                    Account Management
# 9                        Equity Trading
# 10                          Derivatives
# 11          Portfolio Accounting Geneva
# 12                 Client GRG Reporting
# 13                     Desktop Services
# 14              Investment Coordination
# 15                       Equity Trading
# 16                       Equity Trading
# 17                             Database
# 18
# 19              Investment Coordination
# 20                 Compliance and Legal
# 21                 Fixed Income Trading
# 22                      Developer Tools
# 23                      Windows Servers
# 24
# 25                     Asset Allocation
# 26                  Fund Administration
# 27              Relationship Management
# 28                             Database
# 29                      Windows Servers
# ...                                 ...
# 2614                          Corporate
# 2615
# 2616
# 2617          Performance & Attribution
# 2618
# 2619                            Finance
# 2620                  Internet Services
# 2621
# 2622
# 2623                Fund Administration
# 2624             Portfolio Construction
# 2625                Document Management
# 2626                    Developer Tools
# 2627                Document Management
# 2628
# 2629
# 2630                    Human Resources
# 2631
# 2632               Client GRG Reporting
# 2633                   Desktop Services
# 2634
# 2635
# 2636                 Account Management
# 2637             Portfolio Construction
# 2638
# 2639                        Market Data
# 2640                         Regulatory
# 2641                    Windows Servers
# 2642             Derivatives Operations
# 2643               Compliance and Legal
#
# [2644 rows x 11 columns]

# %%
app2app = clean_json_return_df('cmdb_rel_ci_list.json','cl-app2appp.json')

# %%
app2app.columns.tolist()
# Out:
# [u'__status',
#  u'child',
#  u'connection_strength',
#  u'dv_child',
#  u'dv_connection_strength',
#  u'dv_parent',
#  u'dv_percent_outage',
#  u'dv_port',
#  u'dv_sys_created_by',
#  u'dv_sys_created_on',
#  u'dv_sys_id',
#  u'dv_sys_mod_count',
#  u'dv_sys_tags',
#  u'dv_sys_updated_by',
#  u'dv_sys_updated_on',
#  u'dv_type',
#  u'parent',
#  u'percent_outage',
#  u'port',
#  u'sys_created_by',
#  u'sys_created_on',
#  u'sys_id',
#  u'sys_mod_count',
#  u'sys_tags',
#  u'sys_updated_by',
#  u'sys_updated_on',
#  u'type']

# %%
app2app_cols=["child","__status","connection_strength","dv_parent","dv_child"]

# %%
app2app[app2app_cols]
# Out:
#                                  child __status connection_strength  \
# 0     221650f4d40b9100f36d07695bd780af  success          occasional
# 1     85112e27692b950426cdb070c6084ef9  success          occasional
# 2     00d7f3aa59906404fe1fd7f06d36fc58  success          occasional
# 3     0153c71d29e29d8826cd3a40979ed213  success          occasional
# 4     0153c71d29e29d8826cd3a40979ed213  success              always
# 5     05bcffc40ffcc6c4b62ad23be1050e99  success          occasional
# 6     09d2c42a0a0a3c1b0014b99fc2251fd9  success          occasional
# 7     09d663260a0a3c1b00eb26498f1553a2  success          occasional
# 8     0b3531b8995b740426cdb28bf7bcea9a  success          occasional
# 9     0cc6ec9119cdd90408b7c38d86c5167f  success          occasional
# 10    0d4196d49439644426cd898a26eb8a6d  success          occasional
# 11    0e2547dd29e29d8826cd3a40979ed2ea  success              always
# 12    0e2547dd29e29d8826cd3a40979ed2ea  success          occasional
# 13    117ca2480f777940661b563be1050e4b  success          occasional
# 14    13d478bf7dadf440f36d35fa4279e960  success          occasional
# 15    15de279724427800f36d32d19034eee8  success          occasional
# 16    18f372b2856df90008b7c4afef06d689  success          occasional
# 17    19024ee7458f858008b71684cad65559  success          occasional
# 18    20aca1fb09779d84f36d81dbab024310  success          occasional
# 19    22a8e689fc6d2404f36d615ec484bf91  success          occasional
# 20    2465c9b09957740426cdb28bf7bcea47  success          occasional
# 21    2559f9690a0a3c1b0165407d8d1ac9e9  success          occasional
# 22    281589f294f0e80026cd898a26eb8ae0  success          occasional
# 23    2838b282f512650026cd8769764e2d64  success          occasional
# 24    2ac2332f7de5f440f36d35fa4279e995  success              always
# 25    2ac2332f7de5f440f36d35fa4279e995  success              always
# 26    2ac2332f7de5f440f36d35fa4279e995  success          occasional
# 27    2bef942b6d04fd00b0951825954ce068  success          occasional
# 28    2c8cb9aac860f50008b78f4db8fb8a29  success          occasional
# 29    2dcd6f5724427800f36d32d19034eed4  success          occasional
# ...                                ...      ...                 ...
# 2768  6963efbf0a0a3c1b00628afaac8f5541  success              always
# 2769  6963efbf0a0a3c1b00628afaac8f5541  success          occasional
# 2770  6963efbf0a0a3c1b00628afaac8f5541  success          occasional
# 2771  6963efbf0a0a3c1b00628afaac8f5541  success          occasional
# 2772  6963f1030a0a3c1b0008e38c18e614e7  success              always
# 2773  6963f1030a0a3c1b0008e38c18e614e7  success          occasional
# 2774  6963f1030a0a3c1b0008e38c18e614e7  success              always
# 2775  8a04e2bf0a0a3c1b01e762bbb7f0e2f1  success          occasional
# 2776  8a10b5df0a0a3c1b007e2958681fb5d7  success          occasional
# 2777  8e1864b90a0a3c1b01af6776fb814a8b  success          occasional
# 2778  9a17447f7d69f440f36d35fa4279e91f  success          occasional
# 2779  a27347130a0a3c57011df2e8cd73362a  success              always
# 2780  a27347130a0a3c57011df2e8cd73362a  success          occasional
# 2781  a6d130650a0a3c5701ae3690ee12a951  success          occasional
# 2782  a76b1fe57d797080f36d35fa4279e99b  success          occasional
# 2783  ad7b6be60a0a3c1b014ec2339202f175  success          occasional
# 2784  b24e4fa10a0a3c57000cdc56c90fae3c  success          occasional
# 2785  b88234b57c743940b0956ea5f4c38616  success          occasional
# 2786  cbb1ae950a0a3c1b019986668c672b5f  success          occasional
# 2787  d51bad330a0a3c57014229097ebec9f2  success          occasional
# 2788  d635724809cc61c4f36d81dbab02435f  success          occasional
# 2789  efab06c20a0a3c1b0008fe2fd83a48a7  success          occasional
# 2790  f003e47e0a0a3c1b00719777bea51b11  success          occasional
# 2791  f4880ca10a0a3c1b00c53f47ada63d02  success          occasional
# 2792  f4920f290a0a3c1b001fe3bf7fb282bd  success              always
# 2793  f4920f290a0a3c1b001fe3bf7fb282bd  success              always
# 2794  f4920f290a0a3c1b001fe3bf7fb282bd  success              always
# 2795  f4920f290a0a3c1b001fe3bf7fb282bd  success          occasional
# 2796  f4991bc80a0a3c1b013abcf0fd8564a7  success          occasional
# 2797  ffbfbbfdf4633440f36db551f0141ea4  success          occasional
#
#                                       dv_parent  \
# 0                                      Security
# 1                                       Network
# 2                   Portfolio Accounting Geneva
# 3                                Equity Trading
# 4                                        GTS EQ
# 5                                Equity Trading
# 6                          Client GRG Reporting
# 7                          Client GRG Reporting
# 8                          Client GRG Reporting
# 9                           Email and Messaging
# 10                          Document Management
# 11                                       GTS EQ
# 12                               Equity Trading
# 13                          Email and Messaging
# 14                              Human Resources
# 15                                      Finance
# 16                    Infrastructure Monitoring
# 17                         Compliance and Legal
# 18                               Equity Trading
# 19                         Client GRG Reporting
# 20                         Client GRG Reporting
# 21    Cash and Investment Support Liaison Group
# 22                             Asset Allocation
# 23                              Windows Servers
# 24            Contracts Management System (CMS)
# 25                                   Documentum
# 26                          Document Management
# 27                                 Architecture
# 28                         Compliance and Legal
# 29                                      Finance
# ...                                         ...
# 2768                          Alpha Rank System
# 2769                    Dow Jones Islamic Index
# 2770       Dow Jones Wilshire US Family Indexes
# 2771                                Market Data
# 2772                                     GTS EQ
# 2773                                Market Data
# 2774              EPS - Enterprise Price Server
# 2775                                Market Data
# 2776                                Market Data
# 2777                                Market Data
# 2778                                Market Data
# 2779                           FIQS - FX Models
# 2780                                Market Data
# 2781                                Market Data
# 2782                                Market Data
# 2783                                Market Data
# 2784                                Market Data
# 2785                                Market Data
# 2786                                Market Data
# 2787                                Market Data
# 2788                  Infrastructure Monitoring
# 2789                                Market Data
# 2790                                Market Data
# 2791                                Market Data
# 2792                                     GTS EQ
# 2793                                OTS (Linux)
# 2794                                    GTS EQD
# 2795                                Market Data
# 2796                                Market Data
# 2797                                Market Data
#
#                                            dv_child
# 0                            OpenID Connect Service
# 1                                         Riverbed2
# 2                                    Geneva Clients
# 3                                   GTS EQ Launcher
# 4                                   GTS EQ Launcher
# 5              GTS EQ Data Maintenance Application
# 6                                  ER Administrator
# 7                                        ER Console
# 8                           ER - IDDS (ER for IDDS)
# 9                                     Message Stats
# 10                        Sharepoint Batch Printing
# 11                                    GTS EQ Client
# 12                                    GTS EQ Client
# 13                   AirWatch Secure Content Locker
# 14                           United Healthcare Link
# 15      Peoplesoft Financials - Resource Management
# 16                        GM-Global Performance POC
# 17                       Compliance Simulator & OOC
# 18                     GTS EQ Deal Interest Monitor
# 19                       Hedge Fund OBI Application
# 20                 ER - Fund Administration (FA ER)
# 21                            Cash Monitoring Batch
# 22                                  AA Risk Metrics
# 23                  WMC_MYPC_DEFAULT_PRINTER_FIX_01
# 24                                 Documentum - CMS
# 25                                 Documentum - CMS
# 26                                 Documentum - CMS
# 27                        SLA Dashboard Test Driver
# 28                                       BEAST - EQ
# 29             Peoplesoft Financials - eProcurement
# ...                                             ...
# 2768                            Factset Workstation
# 2769                            Factset Workstation
# 2770                            Factset Workstation
# 2771                            Factset Workstation
# 2772              Reuters Market Data System (RMDS)
# 2773              Reuters Market Data System (RMDS)
# 2774              Reuters Market Data System (RMDS)
# 2775                                       EZ Edgar
# 2776                                     EZ Insider
# 2777                                    IPC Turrets
# 2778                                           IPTV
# 2779                                 Bloomberg - MW
# 2780                                 Bloomberg - MW
# 2781                                       NYSE FIX
# 2782                                      IPC Unigy
# 2783                                        Simfund
# 2784                                TradeWeb MDLink
# 2785                              DataStream DSGATE
# 2786                                          WONDA
# 2787  IPC Hoot (Enterprise Hoot and Intercom - EHI)
# 2788                                        IPC AFM
# 2789                               Barra Flat Files
# 2790                                     Mercer MPA
# 2791                                        TNS FIX
# 2792                                BT Radianz rFIX
# 2793                                BT Radianz rFIX
# 2794                                BT Radianz rFIX
# 2795                                BT Radianz rFIX
# 2796                                     DTCC SMART
# 2797                          Thomson Reuters Eikon
#
# [2798 rows x 5 columns]

# %%
apps = clean_json_return_df('cmdb_ci_service_list.json','cl-apps.json')

# %%
# Out:
#        discovery_source  due_in  fault_count  sys_mod_count
# count                 0       0         2644    2644.000000
# mean                NaN     NaN            0      10.182678
# std                 NaN     NaN            0       9.919593
# min                 NaN     NaN            0       0.000000
# 25%                 NaN     NaN            0       3.000000
# 50%                 NaN     NaN            0       7.000000
# 75%                 NaN     NaN            0      16.000000
# max                 NaN     NaN            0      60.000000
